# %%
# Enable better logging inside the JupyterLite notebook for Pyodide
#  e.g. for package loading
import ipyloglite

# %%
# %pip install basemap
# Out:
# [pyodide]: Loading basemap, basemap-data, numpy, cycler, distutils, matplotlib, fonttools, kiwisolver, pillow, python-dateutil, pytz, matplotlib-pyodide, pyproj, certifi, pyshp
# [pyodide]: Loaded cycler, kiwisolver, distutils, fonttools, pyshp, matplotlib-pyodide, certifi, python-dateutil, pytz, basemap-data, pillow, pyproj, numpy, matplotlib, basemap

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

m = Basemap(
    width=12000000, height=9000000, projection='lcc', resolution='c',
    lat_1=45, lat_2=55, lat_0=50, lon_0=-107,
)
m.drawcoastlines(color='white')
m.fillcontinents(color='white', alpha=0.25)
m.bluemarble()

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
